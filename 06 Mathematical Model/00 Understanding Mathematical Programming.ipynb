# %% [markdown]
# ![Mthematical%20Programming_01.PNG](attachment:Mthematical%20Programming_01.PNG)

# %% [markdown]
# ![Mthematical%20Programming_02.PNG](attachment:Mthematical%20Programming_02.PNG)

# %%
# Example

# %% [markdown]
# ![Mthematical%20Programming_Example_FoodDiet.PNG](attachment:Mthematical%20Programming_Example_FoodDiet.PNG)

# %% [markdown]
# ![Mthematical%20Programming_Linear%20Programming.PNG](attachment:Mthematical%20Programming_Linear%20Programming.PNG)

# %% [markdown]
# ![Mthematical%20Programming_Terimologies01.PNG](attachment:Mthematical%20Programming_Terimologies01.PNG)

# %% [markdown]
# ![Steps%20to%20build%20First%20model.PNG](attachment:Steps%20to%20build%20First%20model.PNG)
