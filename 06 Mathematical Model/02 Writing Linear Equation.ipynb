# %% [markdown]
# ![#01%20Linear%20Programming.png](attachment:#01%20Linear%20Programming.png)

# %% [markdown]
# ![#02%20Linear%20Programming_Example.PNG](attachment:#02%20Linear%20Programming_Example.PNG)

# %%
# Example 1

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %%
# Example 2

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %%
# Example 13

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %%
# Example 3

# %% [markdown]
# ![1.PNG](attachment:1.PNG)
