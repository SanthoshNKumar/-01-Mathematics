# %%
# Optimise

# %% [markdown]
# ![#01%20Why%20Optimize.PNG](attachment:#01%20Why%20Optimize.PNG)

# %% [markdown]
# ![How%20to%20use%20Optimizer.png](attachment:How%20to%20use%20Optimizer.png)

# %% [markdown]
# ![What%20is%20Optimizer.png](attachment:What%20is%20Optimizer.png)
