# %% [markdown]
# ![Graphing%20Linear%20Equation_00.PNG](attachment:Graphing%20Linear%20Equation_00.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_01.PNG](attachment:Graphing%20Linear%20Equation_01.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_02.PNG](attachment:Graphing%20Linear%20Equation_02.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_03.PNG](attachment:Graphing%20Linear%20Equation_03.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_04.PNG](attachment:Graphing%20Linear%20Equation_04.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_05_.PNG](attachment:Graphing%20Linear%20Equation_05_.PNG)

# %% [markdown]
# ![Graphing%20Linear%20Equation_05__.PNG](attachment:Graphing%20Linear%20Equation_05__.PNG)
