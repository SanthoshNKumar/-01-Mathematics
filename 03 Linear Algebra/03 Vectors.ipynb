# %% [markdown]
# ## Pythogorean Theorem

# %% [markdown]
# ![Pythogorean%20Theorem_2.PNG](attachment:Pythogorean%20Theorem_2.PNG)

# %% [markdown]
# ![Pythogorean%20Theorem_1.PNG](attachment:Pythogorean%20Theorem_1.PNG)

# %% [markdown]
# ## Vector

# %% [markdown]
# ![Vector.PNG](attachment:Vector.PNG)

# %% [markdown]
# ## Vector and Scaler

# %% [markdown]
# ![Vector%20and%20Scaler.PNG](attachment:Vector%20and%20Scaler.PNG)

# %% [markdown]
# ## Vectors

# %% [markdown]
# ![Vectors.PNG](attachment:Vectors.PNG)

# %% [markdown]
# ## Vector_2 Dimensions

# %% [markdown]
# ![Vector_2%20Dimensions.PNG](attachment:Vector_2%20Dimensions.PNG)

# %% [markdown]
# ## Vector_3 Dimensions

# %% [markdown]
# ![Vector_3%20Dimensions.PNG](attachment:Vector_3%20Dimensions.PNG)

# %% [markdown]
# ## Vector_Orthogonal

# %% [markdown]
# ![Vector_Orthogonal.PNG](attachment:Vector_Orthogonal.PNG)

# %% [markdown]
# ![Vector_Orthogonal_01.PNG](attachment:Vector_Orthogonal_01.PNG)

# %% [markdown]
# ## Vector_Properteis

# %% [markdown]
# ![Vector_Properteis.PNG](attachment:Vector_Properteis.PNG)

# %% [markdown]
# ## Vector_Unit Vector

# %% [markdown]
# ![Vector_Unit%20Vector_00.png](attachment:Vector_Unit%20Vector_00.png)

# %% [markdown]
# ![Vector_Unit%20Vector.png](attachment:Vector_Unit%20Vector.png)

# %% [markdown]
# ## Vector Norm

# %% [markdown]
# ![Vector_VectorNorm.png](attachment:Vector_VectorNorm.png)

# %% [markdown]
# ## Zero(null) Vector

# %% [markdown]
# ![Vector_Zero%28null%29%20Vector.png](attachment:Vector_Zero%28null%29%20Vector.png)

# %% [markdown]
# ## Vectors_Finding Hypothnious

# %% [markdown]
# ![Vectors_Finding%20Hypothnious.PNG](attachment:Vectors_Finding%20Hypothnious.PNG)

# %% [markdown]
# ## Vector_Find Angle Between Vector

# %% [markdown]
# ![Vector_Find%20Angle%20Between%20Vector.PNG](attachment:Vector_Find%20Angle%20Between%20Vector.PNG)

# %% [markdown]
# ## Vector_Mangniture Of Vector

# %% [markdown]
# ![Vector_Mangniture%20Of%20Vector.PNG](attachment:Vector_Mangniture%20Of%20Vector.PNG)

# %% [markdown]
# ## Vector_Addition

# %% [markdown]
# ![Vector_Addition.PNG](attachment:Vector_Addition.PNG)

# %% [markdown]
# ![Vector_Addition_00.PNG](attachment:Vector_Addition_00.PNG)

# %% [markdown]
# ## Vector_Subtraction

# %% [markdown]
# ![Vector_Subtraction.PNG](attachment:Vector_Subtraction.PNG)

# %% [markdown]
# ![Vector_Subtraction_00.PNG](attachment:Vector_Subtraction_00.PNG)

# %% [markdown]
# ## Vector_Multiply Vector by Scaler

# %% [markdown]
# ![Vector_Multiply%20Vector%20by%20Scaler.PNG](attachment:Vector_Multiply%20Vector%20by%20Scaler.PNG)

# %% [markdown]
# ## Vector_Product_Multiply Vectorst

# %% [markdown]
# ![Vector_Product_Multiply%20Vectorst.png](attachment:Vector_Product_Multiply%20Vectorst.png)

# %% [markdown]
# ## Vector Dot Product

# %% [markdown]
# ![Vector%20Dot%20Product.PNG](attachment:Vector%20Dot%20Product.PNG)

# %% [markdown]
# ## Vector_Product_Dot Product

# %% [markdown]
# ![Vector_Product_Dot%20Product.png](attachment:Vector_Product_Dot%20Product.png)

# %% [markdown]
# ## Vector Inner and Outer Product

# %% [markdown]
# ![Vector%20Inner%20and%20Outer%20Product.PNG](attachment:Vector%20Inner%20and%20Outer%20Product.PNG)

# %% [markdown]
# ## Vector_Product_Cross Product

# %% [markdown]
# ![Vector_Product_Cross%20Product.png](attachment:Vector_Product_Cross%20Product.png)

# %% [markdown]
# ## Vector_Product_Cross Product_Calculation

# %% [markdown]
# ![Vector_Product_Cross%20Product_Calculation.png](attachment:Vector_Product_Cross%20Product_Calculation.png)
