# %% [markdown]
# ## Equation

# %% [markdown]
# ![Linear%20Algebra_Basics_01_Equation.png](attachment:Linear%20Algebra_Basics_01_Equation.png)

# %% [markdown]
# ## Binominal_Polynominal

# %% [markdown]
# ![Linear%20Algebra_Basics_02_Binominal_Polynominal_.png](attachment:Linear%20Algebra_Basics_02_Binominal_Polynominal_.png)

# %% [markdown]
# ## Exponent

# %% [markdown]
# ![Linear%20Algebra_Basics_02_Exponent.png](attachment:Linear%20Algebra_Basics_02_Exponent.png)

# %% [markdown]
# ## Negative Exponent

# %% [markdown]
# ![Linear%20Algebra_Basics_02_Negative%20Exponent.png](attachment:Linear%20Algebra_Basics_02_Negative%20Exponent.png)

# %% [markdown]
# ## Reciprocal

# %% [markdown]
# ![Linear%20Algebra_Basics_03_Reciprocal.png](attachment:Linear%20Algebra_Basics_03_Reciprocal.png)

# %% [markdown]
# ## CubeRoot

# %% [markdown]
# ![Linear%20Algebra_Basics_04_CubeRoot.png](attachment:Linear%20Algebra_Basics_04_CubeRoot.png)

# %% [markdown]
# ## nthRoot

# %% [markdown]
# ![Linear%20Algebra_Basics_04_nthRoot.png](attachment:Linear%20Algebra_Basics_04_nthRoot.png)

# %% [markdown]
# ## SquareRoot

# %% [markdown]
# ![Linear%20Algebra_Basics_04_SquareRoot.png](attachment:Linear%20Algebra_Basics_04_SquareRoot.png)

# %% [markdown]
# ## DistanceBetweenTwoPoints

# %% [markdown]
# ![Linear%20Algebra_Basics_05_DistanceBetweenTwoPoints.png](attachment:Linear%20Algebra_Basics_05_DistanceBetweenTwoPoints.png)

# %% [markdown]
# ## EquationForStrightLine

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForStrightLine.png](attachment:Linear%20Algebra_Basics_06_EquationForStrightLine.png)

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForStrightLine_.png](attachment:Linear%20Algebra_Basics_06_EquationForStrightLine_.png)

# %%
# Example 2:

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForStrightLine_01.png](attachment:Linear%20Algebra_Basics_06_EquationForStrightLine_01.png)

# %%
# Example 3:

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForStrightLine_02.png](attachment:Linear%20Algebra_Basics_06_EquationForStrightLine_02.png)

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForStrightLine_02_.png](attachment:Linear%20Algebra_Basics_06_EquationForStrightLine_02_.png)

# %% [markdown]
# ## EquationForVerticleStrightLine

# %% [markdown]
# ![Linear%20Algebra_Basics_06_EquationForVerticleStrightLine.png](attachment:Linear%20Algebra_Basics_06_EquationForVerticleStrightLine.png)

# %% [markdown]
# ## StrightLineEquationNotation

# %% [markdown]
# ![Linear%20Algebra_Basics_06_StrightLineEquationNotation.png](attachment:Linear%20Algebra_Basics_06_StrightLineEquationNotation.png)

# %% [markdown]
# ## StrightLineFindMidpoint

# %% [markdown]
# ![Linear%20Algebra_Basics_06_StrightLineFindMidpoint.png](attachment:Linear%20Algebra_Basics_06_StrightLineFindMidpoint.png)

# %% [markdown]
# ## StrightLineParallerLines

# %% [markdown]
# ![Linear%20Algebra_Basics_06_StrightLineParallerLines.png](attachment:Linear%20Algebra_Basics_06_StrightLineParallerLines.png)

# %% [markdown]
# ## StrightLineParpendicularLines

# %% [markdown]
# ![Linear%20Algebra_Basics_06_StrightLineParpendicularLines.png](attachment:Linear%20Algebra_Basics_06_StrightLineParpendicularLines.png)

# %% [markdown]
# ## StrightLineYIntercept

# %% [markdown]
# ![Linear%20Algebra_Basics_06_StrightLineYIntercept.png](attachment:Linear%20Algebra_Basics_06_StrightLineYIntercept.png)

# %% [markdown]
# ## Logarithm

# %% [markdown]
# ![Linear%20Algebra_Basics_07_Logarithm.png](attachment:Linear%20Algebra_Basics_07_Logarithm.png)

# %% [markdown]
# ## Logarithm_Base10

# %% [markdown]
# ![Linear%20Algebra_Basics_07_Logarithm_Base10.png](attachment:Linear%20Algebra_Basics_07_Logarithm_Base10.png)

# %% [markdown]
# ## Logarithm_Exponent

# %% [markdown]
# ![Linear%20Algebra_Basics_07_Logarithm_Exponent.png](attachment:Linear%20Algebra_Basics_07_Logarithm_Exponent.png)

# %% [markdown]
# ## Logarithm_NegativeLogarithm

# %% [markdown]
# ![Linear%20Algebra_Basics_07_Logarithm_NegativeLogarithm.png](attachment:Linear%20Algebra_Basics_07_Logarithm_NegativeLogarithm.png)

# %% [markdown]
# ## Scaler_Vector_Matrix

# %% [markdown]
# ![Linear%20Algebra_Basics_Scaler_Vector_Matrix.png](attachment:Linear%20Algebra_Basics_Scaler_Vector_Matrix.png)
