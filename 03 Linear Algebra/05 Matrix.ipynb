# %% [markdown]
# ## Matrix

# %% [markdown]
# ![Matrices_01.PNG](attachment:Matrices_01.PNG)

# %% [markdown]
# ## Matrix Addition

# %% [markdown]
# ![Matrices_02_Addition.PNG](attachment:Matrices_02_Addition.PNG)

# %% [markdown]
# ## Matrix Subtraction

# %% [markdown]
# ![Matrices_02_Subtraction.PNG](attachment:Matrices_02_Subtraction.PNG)

# %% [markdown]
# ## Matrix Multiply Constants

# %% [markdown]
# ![Matrices_04_MultiplyConstant.PNG](attachment:Matrices_04_MultiplyConstant.PNG)

# %% [markdown]
# ## Matrix Multplication

# %% [markdown]
# ![Matrices_05_MatrixMultplication.PNG](attachment:Matrices_05_MatrixMultplication.PNG)

# %% [markdown]
# ## Matrix Divide

# %% [markdown]
# ![Matrices_06_Divide.PNG](attachment:Matrices_06_Divide.PNG)

# %% [markdown]
# ## Matrix Transposing

# %% [markdown]
# ![Matrices_07_Transposing.PNG](attachment:Matrices_07_Transposing.PNG)

# %% [markdown]
# ## Identity Matrix

# %% [markdown]
# ![Matrices_08_IdentityMatrix.PNG](attachment:Matrices_08_IdentityMatrix.PNG)

# %% [markdown]
# ![Matrices_09_DiagonalMatrix.PNG](attachment:Matrices_09_DiagonalMatrix.PNG)

# %% [markdown]
# ![Matrices_10_SymmetricMatrix.PNG](attachment:Matrices_10_SymmetricMatrix.PNG)

# %% [markdown]
# ![Matrices_11_InverseMatrix.PNG](attachment:Matrices_11_InverseMatrix.PNG)

# %% [markdown]
# ![Matrices_12_SquareMatrix.PNG](attachment:Matrices_12_SquareMatrix.PNG)

# %% [markdown]
# ## Matrix Transformation

# %% [markdown]
# ![Matrices_13_MatrixTransformation.PNG](attachment:Matrices_13_MatrixTransformation.PNG)
