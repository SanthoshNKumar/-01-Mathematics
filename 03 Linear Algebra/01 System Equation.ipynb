# %% [markdown]
# ## System Equation Find The Equation of A Line Given Two Points

# %% [markdown]
# ![System%20Equation%20Find%20The%20Equation%20of%20A%20Line%20Given%20Two%20Points%20.PNG](attachment:System%20Equation%20Find%20The%20Equation%20of%20A%20Line%20Given%20Two%20Points%20.PNG)

# %% [markdown]
# ## System Equation Solving_Add_Elemination

# %% [markdown]
# ![System%20Equation%20Solving_Add_Elemination.PNG](attachment:System%20Equation%20Solving_Add_Elemination.PNG)

# %% [markdown]
# ## System Equation Solving_Multiply_Elemination

# %% [markdown]
# ![System%20Equation%20Solving_Multiply_Elemination.PNG](attachment:System%20Equation%20Solving_Multiply_Elemination.PNG)

# %% [markdown]
# ## System Equation Solving_Subtraction_Elemination

# %% [markdown]
# ![System%20Equation%20Solving_Subtraction_Elemination.PNG](attachment:System%20Equation%20Solving_Subtraction_Elemination.PNG)
