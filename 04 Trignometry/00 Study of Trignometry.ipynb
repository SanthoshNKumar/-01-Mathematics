# %% [markdown]
# ## Trignometry

# %% [markdown]
# ![#00%20What%20is%20Trignometry.png](attachment:#00%20What%20is%20Trignometry.png)

# %%
# 02 Right Angle Triangle

# %% [markdown]
# ![#01%20Trignometry_Right%20Angled%20Triangle%20.png](attachment:#01%20Trignometry_Right%20Angled%20Triangle%20.png)

# %%
# Sine, Cosine and Tanget Theta

# %% [markdown]
# ![#02%20Trignometry_Sine%20Cosine%20and%20Tangent%20%20.png](attachment:#02%20Trignometry_Sine%20Cosine%20and%20Tangent%20%20.png)

# %% [markdown]
# ![#03%20Trignometry_Cotangent%20Secant%20Cosecant%20.png](attachment:#03%20Trignometry_Cotangent%20Secant%20Cosecant%20.png)
