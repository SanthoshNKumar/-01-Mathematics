# %% [markdown]
# ![1_Calculas.PNG](attachment:1_Calculas.PNG)

# %% [markdown]
# ![1_Calculas_01.PNG](attachment:1_Calculas_01.PNG)

# %% [markdown]
# ![1_Calculas_02.PNG](attachment:1_Calculas_02.PNG)

# %% [markdown]
# ![1_Calculas_03.PNG](attachment:1_Calculas_03.PNG)

# %% [markdown]
# ![1_Calculas_04.PNG](attachment:1_Calculas_04.PNG)

# %% [markdown]
# ![2_Calculas_Integration_FindAreaUnderCurve.PNG](attachment:2_Calculas_Integration_FindAreaUnderCurve.PNG)
