# %%
'''
Distance Metrics
    - There are many Distance Metrics
    
        1. Euclidean Distance
        2. Manhattan Distance
        3. Minkowski Distance
        4. Hamming Distance
        5. L1, L2 and Lp norms
        6. Cosine Distance and Similarity

# %% [markdown]
# ![Dis.png](attachment:Dis.png)

# %%
'''
Euclidean Distance: In simple words, Euclidean Distance represents the shortest distance between two points.

Euclidean distance is also known as the L2 norm of a vector.

# %% [markdown]
# ![dis1.png](attachment:dis1.png)

# %%
'''
L2 and L1 Norm

# %% [markdown]
# ![dis3.png](attachment:dis3.png)

# %%
'''
L2 norm: (Euclidean norm) : Direct Route

It is the most popular norm, also known as the Euclidean norm. 
It is the shortest distance to go from one point to another.

the L2 norm is the most direct route.

# %%
'''
Manhattan Distance:

Manhattan distance is also known as Taxicab Geometry, City Block Distance, etc.

When we can use a map of a city, we can give direction by telling people that they should walk/drive two city 
blocks North, then turn left and travel another three city blocks.

# %%
'''
L1 Norm: (Manhattan Distance) : Taxicab Geometry

Also known as Manhattan Distance or Taxicab norm. L1 norm is the sum of the magnitudes of the vectors in space.
It is the most natural way of measure distance between vectors, that is the sum of absolute difference of the components of the 
vectors.

# %% [markdown]
# ![dis2.png](attachment:dis2.png)
